# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("earthquake_data.csv",header=0)

# %%
data
# Out:
#                                                  title  magnitude  \
# 0         M 7.0 - 18 km SW of Malango, Solomon Islands        7.0
# 1             M 6.9 - 204 km SW of Bengkulu, Indonesia        6.9
# 2                                             M 7.0 -         7.0
# 3                  M 7.3 - 205 km ESE of Neiafu, Tonga        7.3
# 4                                             M 6.6 -         6.6
# ..                                                 ...        ...
# 777  M 7.7 - 28 km SSW of Puerto El Triunfo, El Sal...        7.7
# 778              M 6.9 - 47 km S of Old Harbor, Alaska        6.9
# 779             M 7.1 - 16 km NE of Port-Olry, Vanuatu        7.1
# 780                      M 6.8 - Mindanao, Philippines        6.8
# 781           M 7.5 - 21 km SE of Lukatan, Philippines        7.5
#
#             date_time  cdi  mmi  alert  tsunami  sig net  nst   dmin   gap  \
# 0    22-11-2022 02:03    8    7  green        1  768  us  117  0.509  17.0
# ...

# %%
data.describe(include="all")
# Out:
#            title   magnitude         date_time         cdi         mmi  alert  \
# count        782  782.000000               782  782.000000  782.000000    415
# unique       768         NaN               773         NaN         NaN      4
# top     M 6.9 -          NaN  11-01-2022 11:35         NaN         NaN  green
# freq           3         NaN                 3         NaN         NaN    325
# mean         NaN    6.941125               NaN    4.333760    5.964194    NaN
# std          NaN    0.445514               NaN    3.169939    1.462724    NaN
# min          NaN    6.500000               NaN    0.000000    1.000000    NaN
# 25%          NaN    6.600000               NaN    0.000000    5.000000    NaN
# 50%          NaN    6.800000               NaN    5.000000    6.000000    NaN
# 75%          NaN    7.100000               NaN    7.000000    7.000000    NaN
# max          NaN    9.100000               NaN    9.000000    9.000000    NaN
#
# ...

# %%
data.isnull().sum()*100/len(data)
# Out:
# title         0.000000
# magnitude     0.000000
# date_time     0.000000
# cdi           0.000000
# mmi           0.000000
# alert        46.930946
# tsunami       0.000000
# sig           0.000000
# net           0.000000
# nst           0.000000
# dmin          0.000000
# gap           0.000000
# magType       0.000000
# depth         0.000000
# latitude      0.000000
# longitude     0.000000
# location      0.639386
# continent    73.657289
# country      38.107417
# dtype: float64

# %%
data.drop(columns=["alert","continent","country","title","location","date_time"], axis=1, inplace= True)

# %%
data.dtypes
# Out:
# magnitude    float64
# cdi            int64
# mmi            int64
# tsunami        int64
# sig            int64
# net           object
# nst            int64
# dmin         float64
# gap          float64
# magType       object
# depth        float64
# latitude     float64
# longitude    float64
# dtype: object

# %%
tsunami_counts = data["tsunami"].value_counts()
labels = ["No Tsunami", "Tsunami"]
colors = ["skyblue", "lightcoral"]
plt.pie(tsunami_counts, labels=labels, colors=colors, autopct="%1.1f%%", startangle=90)
plt.axis("equal")
plt.title("Tsunami Occurrences")
plt.show()

# %%
data["tsunami"].value_counts(normalize=True)*100
# Out:
# 0    61.12532
# 1    38.87468
# Name: tsunami, dtype: float64

# %%
data["magType"].value_counts()
# Out:
# mww    468
# mwc    217
# mwb     70
# mw      16
# Mi       4
# ms       2
# mb       2
# md       2
# ml       1
# Name: magType, dtype: int64

# %%
sns.countplot(data["magType"])
# Out:
# C:\Users\Madunala Jayanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='magType', ylabel='count'>

# %%
data['magType'].mask(data['magType'] == "mww", 1, inplace=True)
data['magType'].mask(data['magType'] == "mwc", 2, inplace=True)
data['magType'].mask(data['magType'] == "mwb", 3, inplace=True)
data['magType'].mask(data['magType'] == "mw", 4, inplace=True)
data['magType'].mask(data['magType'] == "Mi", 5, inplace=True)
data['magType'].mask(data['magType'] == "ms", 6, inplace=True)
data['magType'].mask(data['magType'] == "mb", 7, inplace=True)
data['magType'].mask(data['magType'] == "md", 8, inplace=True)
data['magType'].mask(data['magType'] == "ml", 9, inplace=True)

# %%
data["net"].value_counts()
# Out:
# us          747
# ak           11
# official      8
# nc            3
# duputel       3
# at            2
# pt            2
# ci            2
# hv            2
# nn            1
# uw            1
# Name: net, dtype: int64

# %%
sns.countplot(data["net"])
# Out:
# C:\Users\Madunala Jayanth\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='net', ylabel='count'>

# %%
data['net'].mask(data['net'] == "us", 1, inplace=True)
data['net'].mask(data['net'] == "ak", 2, inplace=True)
data['net'].mask(data['net'] == "nc", 3, inplace=True)
data['net'].mask(data['net'] == "duputel", 4, inplace=True)
data['net'].mask(data['net'] == "at", 5, inplace=True)
data['net'].mask(data['net'] == "pt", 6, inplace=True)
data['net'].mask(data['net'] == "ci", 7, inplace=True)
data['net'].mask(data['net'] == "hv", 8, inplace=True)
data['net'].mask(data['net'] == "nn", 9, inplace=True)
data['net'].mask(data['net'] == "uw", 10, inplace=True)
data['net'].mask(data['net'] == "official", 11, inplace=True)

# %%
data
# Out:
#      magnitude  cdi  mmi  tsunami  sig net  nst   dmin   gap magType    depth  \
# 0          7.0    8    7        1  768   1  117  0.509  17.0       1   14.000
# 1          6.9    4    4        0  735   1   99  2.229  34.0       1   25.000
# 2          7.0    3    3        1  755   1  147  3.125  18.0       1  579.000
# 3          7.3    5    5        1  833   1  149  1.865  21.0       1   37.000
# 4          6.6    0    2        1  670   1  131  4.998  27.0       1  624.464
# ..         ...  ...  ...      ...  ...  ..  ...    ...   ...     ...      ...
# 777        7.7    0    8        0  912   1  427  0.000   0.0       2   60.000
# 778        6.9    5    7        0  745   2    0  0.000   0.0       4   36.400
# 779        7.1    0    7        0  776   1  372  0.000   0.0       3  103.000
# 780        6.8    0    5        0  711   1   64  0.000   0.0       2   33.000
# 781        7.5    0    7        0  865   1  324  0.000   0.0       2   33.000
#
#      latitude  longitude
# ...

# %%
# data = data.sample(frac=1)
# data

# %%
X = data.drop('tsunami', axis=1)
y = data['tsunami']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, stratify=y, random_state=321)

# %%
# ratio = 0.75

# %%
# total_rows = data.shape[0]
# train_size = int(total_rows*ratio)
# test_size = (total_rows-train_size)

# %%
# X_train = X[0:train_size]
# X_test = X[0:test_size]
# y_train = y[train_size:]
# y_test = y[test_size:]

# %%
X_train
# Out:
#      magnitude  cdi  mmi   sig net  nst   dmin    gap magType   depth  \
# 269        7.6    6    5   957   1    0  3.287   10.0       1  606.21
# 47         6.5    7    5   684   1    0  0.993  114.0       1   21.00
# 356        8.2    9    8  1332   1    0  0.609   23.0       1   25.00
# 696        7.0    0    7   754   1  367  0.000   33.0       2   16.60
# 732        6.6    0    7   670   2    0  0.000    0.0       4    4.20
# ..         ...  ...  ...   ...  ..  ...    ...    ...     ...     ...
# 589        7.0    4    7   768   1  537  0.000   23.1       2   22.00
# 647        7.2    7    7  1104   1  698  0.000   19.6       2   36.00
# 182        7.9    9    4  1870   1    0  2.585   30.0       1   14.06
# 231        6.9    9    6  1144   1    0  0.671   10.0       1    9.00
# 294        6.5    3    4   652   1    0  2.277   11.0       1  460.00
#
#      latitude  longitude
# 269  -10.5372   -70.9437
# 47    12.1598   -87.8542
# 356  -19.6097   -70.7691
# ...

# %%
X_test
# Out:
#      magnitude  cdi  mmi   sig net  nst   dmin   gap magType   depth  \
# 632        7.6    0    8   889   1  579  0.000  18.5       2   22.00
# 439        6.5    7    6  1171   1  599  0.000  54.1       3   20.00
# 656        6.7    5    6   717   1  656  0.000  21.2       2   19.00
# 368        6.6    6    7   723   1    0  0.636  31.0       1   27.00
# 415        6.9    6    7   814   1  686  0.000  28.0       1  107.00
# ..         ...  ...  ...   ...  ..  ...    ...   ...     ...     ...
# 129        8.0    9    8  1890   1    0  3.180  17.0       1  122.57
# 384        6.7    4    5   715   1    0  3.741  22.0       1   12.00
# 539        7.5    7    6  1248   1  303  0.000  18.2       2   24.00
# 323        7.1    4    6   779   1    0  1.397  18.0       1   45.00
# 365        6.5    3    4   651   1    0  5.194  22.0       1  371.00
#
#      latitude  longitude
# 632   60.9490   167.0890
# 439   18.2290  -102.6890
# 656   -1.6440    99.6070
# 368  -30.2921   -71.5215
# ...

# %%
from scipy.stats import chi2_contingency

class CHAIDDecisionTree:
    def __init__(self, alpha=0.05):
        self.alpha = alpha
    
    def fit(self, X, y):
        self.target_variable = y.name
        data = pd.concat([X, y], axis=1)
        self.tree = self._build_tree(data)
    
    def predict(self, X):
        return X.apply(self._traverse_tree, axis=1)
    
    def _build_tree(self, data):
        if data[self.target_variable].nunique() == 1:
            return data[self.target_variable].iloc[0]
        
        best_variable = None
        best_p = 1
        for variable in data.columns:
            if variable == self.target_variable:
                continue
            table = pd.crosstab(data[variable], data[self.target_variable])
            chi2, p, dof, expected = chi2_contingency(table)
            if p < best_p:
                best_variable = variable
                best_p = p
        
        if best_p > self.alpha:
            return data[self.target_variable].mode().iloc[0]
        
        tree = {best_variable: {}}
        for group in self._split_data(data, best_variable):
            value = group[best_variable].iloc[0]
            subtree = self._build_tree(group)
            tree[best_variable][value] = subtree
        
        return tree
    
    def _split_data(self, data, variable):
        groups = data.groupby(variable)
        return [groups.get_group(x) for x in groups.groups]
    
    def _traverse_tree(self, row):
        node = self.tree
        while isinstance(node, dict):
            variable = list(node.keys())[0]
            value = row[variable]
            node = node[variable][value]
        return node

# %%
model1 = CHAIDDecisionTree(alpha=0.05)
model1.fit(X_train, y_train)

# %%
model1.fit(X_test,y_test)

# %%
train_pred=model1.predict(X_train)

# %%
 test_pred=model1.predict(X_test)

# %%
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

print('Accuracy:', accuracy_score(y_train, train_pred))
# Out:
# Accuracy: 0.8756855575868373

# %%
print('Accuracy:', accuracy_score(y_test, test_pred))
# Out:
# Accuracy: 0.7787234042553192
